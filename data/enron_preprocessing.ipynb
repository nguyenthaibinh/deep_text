# %%
from keras.preprocessing import text
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# /Users/binhnguyen/libs/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_enron_data(file_name, top=0):
    df = pd.read_csv(file_name, sep=':##:', engine='python')
    df = df.dropna()
    
    n_len = df.shape[0]
    print("n_len:", n_len)
    
    if isinstance(top, int) and (top > 0) and (top < n_len):
        print("Get top {} rows of the quora.".format(top))
        df = df[:top]
    df['is_pair'] = 1
    
    text1 = list(df['request'])
    text2 = list(df['response'])
    is_pair = list(df['is_pair'])
    
    return text1, text2, is_pair

# %%
ENRON_RAW = "./pre/enron_email/message_pairs.csv"
ENRON_STANDARDIZED = "./pre/enron_email/message_pairs_preprocessed.csv"

# %%
df = pd.read_csv(ENRON_RAW, sep=":##:", engine='python')

# %%
df.head()
# Out:
#                                              request  \
# 0  John Lavorato-M  Mike Grigsby-D Keith Holst-D ...
# 1  Program Importance: High   Hi Phillip.  We app...
# 2  John Lavorato-M  Mike Grigsby-D Keith Holst-D ...
# 3  > > > > George, > >      Can you please call m...
# 4  I am planning to build a house in the Texas hi...
#
#                                             response
# 0  Program Importance: High   Hi Phillip.  We app...
# 1  Program   We have not received your completed ...
# 2  Hi Phillip.  We appreciate your prompt attenti...
# 3  I'll get back to them on this.  I know we have...
# 4  Re. Your living.com inquiry  Thank you for you...

# %%
def text_to_wordlist(text, remove_stopwords=False, stem_words=False):
    # Clean the text, with the option to remove stopwords and to stem words.

    # Convert words to lower case and split them
    text = text.lower().split()

    # Optionally, remove stop words
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        text = [w for w in text.strip() if w not in stops]

    text = " ".join(text)

    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    text = re.sub(r"\t{1,}", " ", text)
    text = re.sub(r"\n", " ", text)
    text = re.sub(r"\"", " ", text)

    # Optionally, shorten words to their stems
    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('english')
        stemmed_words = [stemmer.stem(word.strip()) for word in text]
        text = " ".join(stemmed_words)

    # Return a list of words
    return(text)

# %%
text1, text2, is_pair = load_enron_data(ENRON_RAW)
# Out:
# n_len: 63438

# %%
text1[:10]
# Out:
# ['John Lavorato-M  Mike Grigsby-D Keith Holst-D Frank Ermis-D Steve South-D Janie Tholt-D  Scott Neal-P Hunter Shively-P Tom Martin-P John Arnold-P',
#  "Program Importance: High   Hi Phillip.  We appreciate your prompt attention and completing the Team Selection information.  Ideally, we needed to receive your team of raters on the Team Selection form we sent you.  The information needed is then easily transferred into the database directly from that Excel spreadsheet.  If you do not have the ability to complete that form, inserting what you listed below, we still require additional information.  We need each person's email address.  Without the email address, we cannot email them their internet link and ID to provide feedback for you, nor can we send them an automatic reminder via email.  It would also be good to have each person's phone number, in the event we need to reach them.  So, we do need to receive that complete TS Excel spreadsheet, or if you need to instead, provide the needed information via email.  Thank you for your assistance Phillip.  Christi L. Smith Project Manager for Client Services Keilty, Goldsmith & Company 858/450-2554",
#  'John Lavorato-M  Mike Grigsby-D Keith Holst-D Frank Ermis-D Steve South-D Janie Tholt-D  Scott Neal-P Hunter Shively-P Tom Martin-P John Arnold-P',
#  '> > > > George, > >      Can you please call my credit desk at 713-853-1803.  They have not > received any financials for ACN Power. > > Thanks, > > Phillip Allen > >',
#  'I am planning to build a house in the Texas hillcountry.  The exterior will be a farmhouse style with porches on front and back.  I am considering the following features:  stained and scored concrete floors, an open living/dining/kitchen concept, lots of windows, a home office, 4 bedrooms all upstairs.  I want a very relaxed and comfortable style, but not exactly country.  Can you help?   ========================================== Additional user info: ID = 3052970 email = pallen@enron.com FirstName = phillip LastName = allen',
#  'The topic will the the western natural gas market.  I may have overhead slides.  I will bring handouts.',
#  'Larrry,  I realize you are disappointed about the project.  It is not my desire for you to be left with out of pocket expenses.  The only item from your list that I need further clarification is the $15,000 worth of extensions.  You mentioned that this was applied to the cost of the land and it actually represents your cash investment in the land.  I agree that you should be refunded any cash investment.  My only request is that you help me locate this amount on the closing statement or on some other document.  Phillip',
#  'Importance: High   I=01,ve been asked to provide an updated list on who is authorized to cross= =20 trade what commodities/products.  As soon as possible, please reply to this= =20 email with the names of only the authorized =01&cross commodity=018 traders= and=20 their respective commodities. (natural gas, crude, heat, gasoline, weather,= =20 precip, coal, power, forex (list currency), etc..)  Thanks,  Frank   PS. Traders limited to one commodity do not need to be included on this lis= t.',
#  '> > > Lee, > > My fax number is 713-646-2391.  Please fax me a loan application > that I can > pass on to the buyer. > > Phillip Allen > pallen@enron.com > 713-853-7041 > > > (See attached file: Copy of Loan App.tif) > (See attached file: Copy of Multifamily forms) > >',
#  "> > > Jeff, > > Here is the application from SPB.  I guess they want to use the same form > as a new loan application.  I have a call in to Lee O'Donnell to try to > find out if there is a shorter form.  What do I need to be > providing to the > buyer according to the contract.  I was planning on bringing a copy of the > survey and a rentroll including deposits on Monday.  Please let me know > this morning what else I should be putting together. > > > Phillip > > > > > I was told that you were faxed the loan application.  I will send > attachment > for a backup.  Also, you will need to provide a current rent roll and 1999 > & > 2000 operating history (income & expense). > > Call me if you need some help. > > Thanks > > Lee O'Donnell >"]

# %%
text_to_wordlist("What's \t the step by step guide to invest in share market in india?")
# Out:
# 'what is the step by step guide to invest in share market in india '

# %%
sep = ":##:"
n_len = len(text1)
f = open(ENRON_STANDARDIZED, "w")
f.write("{}{}{}{}{}".format("request", sep, "response", sep, "is_pair"))
for i in range(n_len):
    s1 = ' '.join(text.text_to_word_sequence(text1[i]))
    s2 = ' '.join(text.text_to_word_sequence(text2[i]))
    s1 = text_to_wordlist(s1)
    s2 = text_to_wordlist(s2)
    d = is_pair[i]
    f.write("\n{}{}{}{}{}".format(s1, sep, s2, sep, d))
f.close()

# %%
df = pd.read_csv(ENRON_STANDARDIZED, sep=sep, engine='python')

# %%
df.head(100)
# Out:
#                                               request  \
# 0   john lavorato m mike grigsby d keith holst d f...
# 1   program importance high hi phillip we apprecia...
# 2   john lavorato m mike grigsby d keith holst d f...
# 3   george can you please call my credit desk at 7...
# 4   i am planning to build a house in the texas hi...
# 5   the topic will the the western natural gas mar...
# 6   larrry i realize you are disappointed about th...
# 7   importance high i 01 ve been asked to provide ...
# 8   lee my fax number is 713 646 2391 please fax m...
# 9   jeff here is the application from spb i guess ...
# 10  lee my fax number is 713 646 2391 please fax m...
# 11  jeff the file attached contains an operating s...
# 12  enron global technology is in the process of d...
# 13  this is a summary of the comments we have rece...
# 14  october 17 2001 jeff i talked to your dad and ...
# 15  http www madblast com oska humor bin swf marc ...
# 16  apts phillip i spoke to wendy this morning who...
# 17  lakeline apts michelle i have executed the war...
# 18  randy why is there a pg e citygate position in...
# 19  phillip i forgot to ask if you have a recent s...
# 20  hi phillip and mike is there any way you could...
# 21  phillip pursuant to your request please see th...
# 22  renee thank you for the forms i am trying to e...
# 23  phillip this is the candidate i spoke with you...
# 24  adrianne i cannot download his resume please r...
# 25          phillip lets try this one thanks adrianne
# 26  adrianne i spoke to brent d i would recommend ...
# 27  10 30 01 hi phillip this message is to confirm...
# 28  10 30 01 sheri and i would like to discuss the...
# 29  phillip hope your trip to kerrville was worthw...
# ..                                                ...
# 70  phillip would you have some time wednesday aft...
# 71  works for us i have scheduled 47c1 at 10 30 if...
# 72  jacques have you received the assignment lette...
# 73  good morning pat said you had sent neal an e m...
# 74  phillip i received a fax of the consent agreem...
# 75  also posted today on el paso web site fyi tues...
# 76  hunter scott tom barry we have been meeting wi...
# 77  phillip i think they are not copying you on th...
# 78  this is to quickly summarize our call on july ...
# 79  this is to quickly summarize our call on july ...
# 80  phillip here is the following letter i put the...
# 81  phillip here is info about the party i am havi...
# 82  richard i hope your party was a success sorry ...
# 83  hunter the simulation url is https simweb0 eol...
# 84  jay can you set up one more simulated account ...
# 85  hi phillip simtrader7 has access to all us gas...
# 86  jay my message was confusing i needed one more...
# 87  hi phillip simtrader7 now has the access you r...
# 88             charts for today briefing are attached
# 89  phillip i am thinking of speaking with questar...
# 90  phillip if its not to much trouble could you h...
# 91  phillip if its not to much trouble could you h...
# 92  phillip thought this might be of interest ray ...
# 93  phillip i received an email from kevin kolb wi...
# 94  phillip thanks for the prayers call me monday ...
# 95  do you know what they are planning for mountai...
# 96  hello allen i remember you calling and asking ...
# 97  utility construction escrow am amhpleander doc...
# 98  do you know what they are planning for mountai...
# 99  site i do not know much about the beaver creek...
#
#                                              response  is_pair
# 0   program importance high hi phillip we apprecia...        1
# 1   program we have not received your completed te...        1
# 2   hi phillip we appreciate your prompt attention...        1
# 3   i will get back to them on this i know we have...        1
# 4   re your living com inquiry thank you for your ...        1
# 5   ina can you please forward the presentation to...        1
# 6   jacques here is larry lewter response to my re...        1
# 7   john did you put frank hayden up to this if th...        1
# 8   jeff here is the application from spb i guess ...        1
# 9   here is what you need to bring updated rent ro...        1
# 10  jeff here is the application from spb i guess ...        1
# 11  i will talk to lutz about his share of the leg...        1
# 12  earlier this week enron global technology anno...        1
# 13  updated to include comments received as of fri...        1
# 14  phillip which one should i do the 8x12 is half...        1
# 15                                           too good        1
# 16  lakeline apts michelle i have executed the war...        1
# 17  thanks phillip i should have the reimbursement...        1
# 18    phillip looking into it now i will move them rb        1
# 19  greetings phillip i received your phone messag...        1
# 20  phillip mike per my earlier e mail additionall...        1
# 21  renee thank you for the forms i am trying to e...        1
# 22  phillip the social security and medicare tax h...        1
# 23  adrianne i cannot download his resume please r...        1
# 24          phillip lets try this one thanks adrianne        1
# 25  adrianne i spoke to brent d i would recommend ...        1
# 26                         thank you have a great day        1
# 27  10 30 01 sheri and i would like to discuss the...        1
# 28  that is fine phillip k allen enron c om to mon...        1
# 29  phillip carlos and i will try to respond to yo...        1
# ..                                                ...      ...
# 70  works for us i have scheduled 47c1 at 10 30 if...        1
# 71  ina can you get a conference room on 32 for th...        1
# 72  yes they do need to get approval from southern...        1
# 73  kay i sent a copy of an article discussing oil...        1
# 74  jacques glad to hear their attorney contacted ...        1
# 75  matt make sure this is included in your long t...        1
# 76  phillip i think they are not copying you on th...        1
# 77  barry mike and i are going to meet with john l...        1
# 78  please add the following names to the mailing ...        1
# 79  mike i sent leslie a note to include you and o...        1
# 80  please approve ina rangel for a corporate amer...        1
# 81  richard i hope your party was a success sorry ...        1
# 82  would have loved to have you we had lots of be...        1
# 83  jay can you set up one more simulated account ...        1
# 84  hi phillip simtrader7 has access to all us gas...        1
# 85  jay my message was confusing i needed one more...        1
# 86  hi phillip simtrader7 now has the access you r...        1
# 87  jay final request and i will leave you alone n...        1
# 88  hunter here is portland weekly fundamental pre...        1
# 89                                call barry tycholiz        1
# 90  griff can you please accommodate this request ...        1
# 91  dexter hopefully griff gray has sent you the i...        1
# 92  janie do you want to work with regulatory to m...        1
# 93  i am glad we finally heard from kevin kolb i w...        1
# 94  jacques if your schedule permits 4pm or later ...        1
# 95  mark the planned mountain bike activity is on ...        1
# 96  ceci i would like to stay current on listings ...        1
# 97  michelle please send the revised agreements wh...        1
# 98  site i do not know much about the beaver creek...        1
# 99  vail sounds good if we are only going downhill...        1
#
# [100 rows x 3 columns]
